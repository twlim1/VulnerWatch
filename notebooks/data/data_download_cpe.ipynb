# %% [markdown]
# **Title**: Download CPE data\
# **Description**: Notebook to download all CPE data\
# **Developer**: Teck Lim\
# **Create date**: 03/28/2021

# %%
# !pip install requests==2.25.1
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests==2.25.1 in c:\program files\python39\lib\site-packages (2.25.1)
# Requirement already satisfied: idna<3,>=2.5 in c:\program files\python39\lib\site-packages (from requests==2.25.1) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\program files\python39\lib\site-packages (from requests==2.25.1) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\program files\python39\lib\site-packages (from requests==2.25.1) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\program files\python39\lib\site-packages (from requests==2.25.1) (1.26.2)

# %%
import requests
import json
import time

# %%
file_path = '../../data/raw/cpe.json'

# %%
base_url = 'https://services.nvd.nist.gov/rest/json/cpes/1.0'
page_size = 5000
sleep_duration = 3

# %%
def scrap_cpe(total_page=1000, start_page=0):
    cpe_items = list()
    for page_no in range(start_page, total_page):
        for attempt in range(5):
            try:
                print('Retriving page: {}'.format(page_no+1))
                url = '{}?startIndex={}&resultsPerPage={}'.format(base_url, page_no*page_size, page_size)
                response = requests.get(url)
                response_json = response.json()
                break
            except:
                print('Something is wrong. Sleep for {} sec before retrying'.format(sleep_duration))
                time.sleep(sleep_duration)
        else:
            raise BaseException('Exhausted all attempts')

        cpe_items += response_json['result']['cpes']          
        print('Total scrapped: {}'.format(len(cpe_items)))
        if len(cpe_items) + (start_page * total_page) == response_json['totalResults']:
            print('Completed scrapping..')
            break
        time.sleep(sleep_duration)
    return cpe_items

# %%
items = scrap_cpe()
data = json.dumps(items)
with open(file_path, 'w') as fp:
    fp.write(data)
# Out:
# Retriving page: 1
# Total scrapped: 5000
# Retriving page: 2
# Total scrapped: 10000
# Retriving page: 3
# Total scrapped: 15000
# Retriving page: 4
# Total scrapped: 20000
# Retriving page: 5
# Total scrapped: 25000
# Retriving page: 6
# Total scrapped: 30000
# Retriving page: 7
# Total scrapped: 35000
# Retriving page: 8
# Total scrapped: 40000
# Retriving page: 9
# Total scrapped: 45000
# Retriving page: 10
# Total scrapped: 50000
# Retriving page: 11
# Total scrapped: 55000
# Retriving page: 12
# Total scrapped: 60000
# Retriving page: 13
# Total scrapped: 65000
# Retriving page: 14
# Total scrapped: 70000
# Retriving page: 15
# Total scrapped: 75000
# Retriving page: 16
# Total scrapped: 80000
# Retriving page: 17
# Total scrapped: 85000
# Retriving page: 18
# Total scrapped: 90000
# Retriving page: 19
# Total scrapped: 95000
# Retriving page: 20
# Total scrapped: 100000
# Retriving page: 21
# Total scrapped: 105000
# Retriving page: 22
# Total scrapped: 110000
# Retriving page: 23
# Total scrapped: 115000
# Retriving page: 24
# Total scrapped: 120000
# Retriving page: 25
# Total scrapped: 125000
# Retriving page: 26
# Total scrapped: 130000
# Retriving page: 27
# Total scrapped: 135000
# Retriving page: 28
# Total scrapped: 140000
# Retriving page: 29
# Total scrapped: 145000
# Retriving page: 30
# Total scrapped: 150000
# Retriving page: 31
# Total scrapped: 155000
# Retriving page: 32
# Total scrapped: 160000
# Retriving page: 33
# Total scrapped: 165000
# Retriving page: 34
# Total scrapped: 170000
# Retriving page: 35
# Total scrapped: 175000
# Retriving page: 36
# Total scrapped: 180000
# Retriving page: 37
# Total scrapped: 185000
# Retriving page: 38
# Total scrapped: 190000
# Retriving page: 39
# Total scrapped: 195000
# Retriving page: 40
# Total scrapped: 200000
# Retriving page: 41
# Total scrapped: 205000
# Retriving page: 42
# Total scrapped: 210000
# Retriving page: 43
# Total scrapped: 215000
# Retriving page: 44
# Total scrapped: 220000
# Retriving page: 45
# Total scrapped: 225000
# Retriving page: 46
# Total scrapped: 230000
# Retriving page: 47
# Total scrapped: 235000
# Retriving page: 48
# Total scrapped: 240000
# Retriving page: 49
# Total scrapped: 245000
# Retriving page: 50
# Total scrapped: 250000
# Retriving page: 51
# Total scrapped: 255000
# Retriving page: 52
# Total scrapped: 260000
# Retriving page: 53
# Total scrapped: 265000
# Retriving page: 54
# Total scrapped: 270000
# Retriving page: 55
# Total scrapped: 275000
# Retriving page: 56
# Total scrapped: 280000
# Retriving page: 57
# Total scrapped: 285000
# Retriving page: 58
# Total scrapped: 290000
# Retriving page: 59
# Total scrapped: 295000
# Retriving page: 60
# Total scrapped: 300000
# Retriving page: 61
# Total scrapped: 305000
# Retriving page: 62
# Total scrapped: 310000
# Retriving page: 63
# Total scrapped: 315000
# Retriving page: 64
# Total scrapped: 320000
# Retriving page: 65
# Total scrapped: 325000
# Retriving page: 66
# Total scrapped: 330000
# Retriving page: 67
# Total scrapped: 335000
# Retriving page: 68
# Total scrapped: 340000
# Retriving page: 69
# Total scrapped: 345000
# Retriving page: 70
# Total scrapped: 350000
# Retriving page: 71
# Total scrapped: 355000
# Retriving page: 72
# Total scrapped: 360000
# Retriving page: 73
# Total scrapped: 365000
# Retriving page: 74
# Total scrapped: 370000
# Retriving page: 75
# Total scrapped: 375000
# Retriving page: 76
# Total scrapped: 380000
# Retriving page: 77
# Total scrapped: 385000
# Retriving page: 78
# Total scrapped: 390000
# Retriving page: 79
# Total scrapped: 395000
# Retriving page: 80
# Total scrapped: 400000
# Retriving page: 81
# Total scrapped: 405000
# Retriving page: 82
# Total scrapped: 410000
# Retriving page: 83
# Total scrapped: 415000
# Retriving page: 84
# Total scrapped: 420000
# Retriving page: 85
# Total scrapped: 425000
# Retriving page: 86
# Total scrapped: 430000
# Retriving page: 87
# Total scrapped: 435000
# Retriving page: 88
# Total scrapped: 440000
# Retriving page: 89
# Total scrapped: 445000
# Retriving page: 90
# Total scrapped: 450000
# Retriving page: 91
# Total scrapped: 455000
# Retriving page: 92
# Total scrapped: 460000
# Retriving page: 93
# Total scrapped: 465000
# Retriving page: 94
# Total scrapped: 470000
# Retriving page: 95
# Total scrapped: 475000
# Retriving page: 96
# Total scrapped: 480000
# Retriving page: 97
# Total scrapped: 485000
# Retriving page: 98
# Total scrapped: 490000
# Retriving page: 99
# Total scrapped: 495000
# Retriving page: 100
# Total scrapped: 500000
# Retriving page: 101
# Total scrapped: 505000
# Retriving page: 102
# Total scrapped: 510000
# Retriving page: 103
# Total scrapped: 515000
# Retriving page: 104
# Total scrapped: 520000
# Retriving page: 105
# Total scrapped: 525000
# Retriving page: 106
# Total scrapped: 530000
# Retriving page: 107
# Total scrapped: 535000
# Retriving page: 108
# Total scrapped: 540000
# Retriving page: 109
# Total scrapped: 545000
# Retriving page: 110
# Total scrapped: 550000
# Retriving page: 111
# Total scrapped: 555000
# Retriving page: 112
# Total scrapped: 560000
# Retriving page: 113
# Total scrapped: 565000
# Retriving page: 114
# Total scrapped: 570000
# Retriving page: 115
# Total scrapped: 575000
# Retriving page: 116
# Total scrapped: 580000
# Retriving page: 117
# Total scrapped: 585000
# Retriving page: 118
# Total scrapped: 590000
# Retriving page: 119
# Total scrapped: 595000
# Retriving page: 120
# Total scrapped: 598726
# Completed scrapping..sleep_duration

# %%
len(items)
# Out:
# 598726

# %%
with open(file_path, 'r') as fp:
    data = json.load(fp)

# %%
len(data)
# Out:
# 598726
