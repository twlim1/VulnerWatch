# %% [markdown]
# # Process downloaded CCE XML to panda data frames

# %%
import os
import json
import pandas as pd

# %%
SOURCE_DIR = '../data/sources/cce/'
OUTPUT_DIR = '../data/sources/cce/'

CCE_FILE_NAME = os.path.join(SOURCE_DIR, 'cce-COMBINED-5.20201021_cleaned.xlsx')

# %%
df = pd.read_excel(CCE_FILE_NAME, sheet_name='macOSCatalina')
df
# Out:
#              CCE                                        Rule ID  \
# 0    CCE-84721-0               auth_pam_login_smartcard_enforce
# 1    CCE-84724-4                           auth_smartcard_allow
# 2    CCE-84723-6                auth_pam_sudo_smartcard_enforce
# 3    CCE-84729-3                     auth_ssh_smartcard_enforce
# 4    CCE-84725-1  auth_smartcard_certificate_trust_enforce_high
# ..           ...                                            ...
# 195  CCE-84910-9              pwpolicy_prevent_dictionary_words
# 196  CCE-84850-7                          sysprefs_wifi_disable
# 197  CCE-84742-6                      os_identify_non-org_users
# 198  CCE-84893-7                      os_filevault_user_account
# 199  CCE-84894-5                        os_anti_virus_installed
#
#                                                  Title  \
# 0         Enforce Multifactor Authentication for Login
# 1                       Allow Smartcard Authentication
# ...

# %%
df = pd.read_excel(CCE_FILE_NAME, sheet_name='aix5.3')
df
# Out:
#          CCE ID                                    CCE Description  \
# 0    CCE-5847-9  /export/home should be configured on an approp...
# 1    CCE-5424-7  /var should be configured on an appropriate fi...
# 2    CCE-5710-9  /opt should be configured on an appropriate fi...
# 3    CCE-5662-2  The shell for the root account should be locat...
# 4    CCE-5317-3  Core dump size limits should be set appropriately
# ..          ...                                                ...
# 347  CCE-6035-0  Use of change user functions should be audited...
# 348  CCE-6100-2  Terminal logoffs should be audited or not as a...
# 349  CCE-6157-2  Exit function usage should be audited or not a...
# 350  CCE-6156-4  Hard core dump size limits should be set appro...
# 351  CCE-5751-3  Remote root logins via SSH should be allowed o...
#
#                      CCE Parameters              CCE Technical Mechanisms  \
# 0                    logical volume                             via fstab
# ...

# %%
df = pd.read_excel(CCE_FILE_NAME, sheet_name='apache-httpd1.3')
df
# Out:
#          CCE ID                                    CCE Description  \
# 0   CCE-27905-9  Apache's configuration directory should be own...
# 1   CCE-27713-7  Apache's configuration directory should be own...
# 2   CCE-27582-6  Apache's demo CGI printenv.pl should be availa...
# 3   CCE-27923-2        testcgi should be installed as appropriate.
# 4   CCE-27885-3  The "FollowSymLinks" setting of the DocumentRo...
# ..          ...                                                ...
# 74  CCE-27654-3  The Apache "MinSpareServers" directive should ...
# 75  CCE-27916-6  The Apache "MaxSpareServers" directive should ...
# 76  CCE-27785-5  The "ExecCGI" setting of the DocumentRoot shou...
# 77  CCE-28125-3  The Order directive for all DocumentRoot direc...
# 78  CCE-28116-2  The Order directive for the specified Director...
#
#                                        CCE Parameters  \
# 0                                           (1) group
# ...

# %%
df = pd.read_excel(CCE_FILE_NAME, sheet_name='rhel8')
df
# Out:
#        CCE ID v5                                          CCE Title  \
# 0    CCE-80876-6                Disable debug-shell SystemD Service
# 1    CCE-80826-1           Verify that Interactive Boot is Disabled
# 2    CCE-80785-9             Disable Ctrl-Alt-Del Reboot Activation
# 3    CCE-82186-8  Require Authentication for Emergency Systemd T...
# 4    CCE-80855-0        Require Authentication for Single User Mode
# ..           ...                                                ...
# 696  CCE-82885-5                Ensure LDAP client is not installed
# 697  CCE-82418-5       Enable the LDAP Client For Use in Authconfig
# 698  CCE-82417-7  Configure Certificate Directives for LDAP Use ...
# 699  CCE-82416-9  Configure LDAP Client to Use TLS For All Trans...
# 700  CCE-82415-1                 Uninstall openldap-servers Package
#
#     USGCB Setting         Technical Mechanism  \
# 0         disable               via systemctl
# 1          verify                    via grub
# ...
