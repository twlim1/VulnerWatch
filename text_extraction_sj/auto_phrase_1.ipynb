# %% [markdown]
# # DSE 260A Capston Project - Winter 2021
#
# Author: Saba Janamian
# Created: 1/24/2021
# ----

# %%
import os
import json
import spacy
# Load English tokenizer, tagger, parser, NER and word vectors
nlp = spacy.load("en_core_web_sm")
import pprint
pp = pprint.PrettyPrinter(indent=4)

# %%
with open('data/nvdcve-1.1-2020.json') as f:
    cve_dict = json.load(f)

# %%
corpus = ''
counter = 0
LIMIT = 10
for cve in cve_dict['CVE_Items']:
    desc_list = cve['cve']['description']['description_data']
    for desc in desc_list:
        corpus += desc['value'] +'\n'
    counter += 1
    if counter == LIMIT:
        break

# %%
doc = nlp(corpus)

# %%
dash = '-' * 80
print(dash)
print("{:<50}{:<10}{:<10}".format("TEXT", "POS", "DEP"))
print(dash)
for token in doc:
    # Get the token text, part-of-speech tag and dependency label
    token_text = token.text
    token_pos = token.pos_
    token_dep = token.dep_
    # This is for formatting only
    print(f"{token_text:<50}{token_pos:<10}{token_dep:<10}")
# Out:
# --------------------------------------------------------------------------------
# TEXT                                              POS       DEP
# --------------------------------------------------------------------------------
# In                                                ADP       prep
# getProcessRecordLocked                            PROPN     nsubjpass
# of                                                ADP       prep
# ActivityManagerService.java                       NOUN      pobj
# isolated                                          VERB      amod
# apps                                              NOUN      pobj
# are                                               AUX       auxpass
# not                                               PART      neg
# handled                                           VERB      ROOT
# correctly                                         ADV       advmod
# .                                                 PUNCT     punct
# This                                              DET       nsubj
# could                                             VERB      aux
# lead                                              VERB      ROOT
# to                                                ADP       prep
# local                                             ADJ       amod
# escalation                                        NOUN      pobj
# of                                                ADP       prep
# privilege                                         NOUN      pobj
# with                                              ADP       prep
# no                                                DET       det
# additional                                        ADJ       amod
# execution                                         NOUN      compound
# privileges                                        NOUN      pobj
# needed                                            VERB      acl
# .                                                 PUNCT     punct
# User                                              NOUN      compound
# interaction                                       NOUN      nsubjpass
# is                                                AUX       auxpass
# not                                               PART      neg
# needed                                            VERB      ROOT
# for                                               ADP       prep
# exploitation                                      NOUN      pobj
# .                                                 PUNCT     punct
# Product                                           NOUN      ROOT
# :                                                 PUNCT     punct
# Android                                           PROPN     compound
# Versions                                          NOUN      ROOT
# :                                                 PUNCT     punct
# Android-8.0                                       PROPN     appos
# ,                                                 PUNCT     punct
# Android-8.1                                       PROPN     npadvmod
# ,                                                 PUNCT     punct
# Android-9                                         PROPN     npadvmod
# ,                                                 PUNCT     punct
# and                                               CCONJ     cc
# Android-10                                        PROPN     compound
# Android                                           PROPN     compound
# ID                                                PROPN     conj
# :                                                 PUNCT     punct
# A-140055304                                       NOUN      ROOT
#
#                                                  SPACE
# In                                                ADP       prep
# ih264d_init_decoder                               NOUN      pobj
# of                                                ADP       prep
# ih264d_api.c                                      NOUN      pobj
# ,                                                 PUNCT     punct
# there                                             PRON      expl
# is                                                AUX       ROOT
# a                                                 DET       det
# possible                                          ADJ       attr
# out                                               SCONJ     prep
# of                                                ADP       prep
# bounds                                            NOUN      pobj
# write                                             VERB      advcl
# due                                               ADP       prep
# to                                                ADP       pcomp
# a                                                 DET       det
# use                                               NOUN      pobj
# after                                             ADV       prep
# free                                              ADJ       pcomp
# .                                                 PUNCT     punct
# This                                              DET       nsubj
# could                                             VERB      aux
# lead                                              VERB      ROOT
# to                                                ADP       prep
# remote                                            ADJ       amod
# code                                              NOUN      compound
# execution                                         NOUN      pobj
# with                                              ADP       prep
# no                                                DET       det
# additional                                        ADJ       amod
# execution                                         NOUN      compound
# privileges                                        NOUN      pobj
# needed                                            VERB      acl
# .                                                 PUNCT     punct
# User                                              PROPN     compound
# interaction                                       NOUN      nsubjpass
# is                                                AUX       auxpass
# needed                                            VERB      ROOT
# for                                               ADP       prep
# exploitation                                      NOUN      compound
# Product                                           NOUN      pobj
# :                                                 PUNCT     punct
# Android                                           PROPN     compound
# Versions                                          NOUN      ROOT
# :                                                 PUNCT     punct
# Android-8.0                                       PROPN     appos
# ,                                                 PUNCT     punct
# Android-8.1                                       PROPN     npadvmod
# ,                                                 PUNCT     punct
# Android-9                                         PROPN     npadvmod
# ,                                                 PUNCT     punct
# and                                               CCONJ     cc
# Android-10                                        PROPN     compound
# Android                                           PROPN     compound
# ID                                                PROPN     conj
# :                                                 PUNCT     punct
# A-142602711                                       ADJ       ROOT
#
#                                                  SPACE
# In                                                ADP       prep
# onCreate                                          NOUN      pobj
# of                                                ADP       prep
# InstallStart.java                                 NUM       pobj
# ,                                                 PUNCT     punct
# there                                             PRON      expl
# is                                                AUX       ROOT
# a                                                 DET       det
# possible                                          ADJ       amod
# package                                           NOUN      compound
# validation                                        NOUN      compound
# bypass                                            NOUN      attr
# due                                               ADP       amod
# to                                                ADP       pcomp
# a                                                 DET       det
# time                                              NOUN      nmod
# -                                                 PUNCT     punct
# of                                                ADP       prep
# -                                                 PUNCT     punct
# check                                             NOUN      pobj
# time                                              NOUN      nmod
# -                                                 PUNCT     punct
# of                                                ADP       prep
# -                                                 PUNCT     punct
# use                                               NOUN      pobj
# vulnerability                                     NOUN      pobj
# .                                                 PUNCT     punct
# This                                              DET       nsubj
# could                                             VERB      aux
# lead                                              VERB      ROOT
# to                                                ADP       prep
# local                                             ADJ       amod
# escalation                                        NOUN      pobj
# of                                                ADP       prep
# privilege                                         NOUN      pobj
# with                                              ADP       prep
# no                                                DET       det
# additional                                        ADJ       amod
# execution                                         NOUN      compound
# privileges                                        NOUN      pobj
# needed                                            VERB      acl
# .                                                 PUNCT     punct
# User                                              PROPN     compound
# interaction                                       NOUN      nsubjpass
# is                                                AUX       auxpass
# needed                                            VERB      ROOT
# for                                               ADP       prep
# exploitation                                      NOUN      pobj
# .                                                 PUNCT     punct
# Product                                           NOUN      ROOT
# :                                                 PUNCT     punct
# Android                                           PROPN     compound
# Versions                                          NOUN      ROOT
# :                                                 PUNCT     punct
# Android-8.0                                       PROPN     punct
# Android                                           PROPN     compound
# ID                                                PROPN     ROOT
# :                                                 PUNCT     punct
# A-140195904                                       PROPN     appos
#
#                                                  SPACE
# In                                                ADP       prep
# generateCrop                                      NOUN      pobj
# of                                                ADP       prep
# WallpaperManagerService.java                      NOUN      pobj
# ,                                                 PUNCT     punct
# there                                             PRON      expl
# is                                                AUX       ROOT
# a                                                 DET       det
# possible                                          ADJ       amod
# sysui                                             NOUN      compound
# crash                                             NOUN      attr
# due                                               ADP       prep
# to                                                ADP       pcomp
# image                                             NOUN      pobj
# exceeding                                         VERB      acl
# maximum                                           ADJ       amod
# texture                                           NOUN      compound
# size                                              NOUN      dobj
# .                                                 PUNCT     punct
# This                                              DET       nsubj
# could                                             VERB      aux
# lead                                              VERB      ROOT
# to                                                ADP       prep
# local                                             ADJ       amod
# denial                                            NOUN      pobj
# of                                                ADP       prep
# service                                           NOUN      pobj
# with                                              ADP       prep
# no                                                DET       det
# additional                                        ADJ       amod
# execution                                         NOUN      compound
# privileges                                        NOUN      pobj
# needed                                            VERB      acl
# .                                                 PUNCT     punct
# User                                              NOUN      compound
# interaction                                       NOUN      nsubjpass
# is                                                AUX       auxpass
# not                                               PART      neg
# needed                                            VERB      ROOT
# for                                               ADP       prep
# exploitation                                      NOUN      pobj
# .                                                 PUNCT     punct
# Product                                           NOUN      ROOT
# :                                                 PUNCT     punct
# AndroidVersions                                   X         ROOT
# :                                                 PUNCT     punct
# Android-8.0                                       PROPN     dep
# Android-8.1                                       PROPN     dep
# Android-9                                         PROPN     punct
# Android-10Android                                 NOUN      ROOT
# ID                                                PROPN     ROOT
# :                                                 PUNCT     punct
# A-120847476                                       NUM       ROOT
#
#                                                  SPACE
# In                                                ADP       prep
# btm_read_remote_ext_features_complete             NOUN      pobj
# of                                                ADP       prep
# btm_acl.cc                                        PROPN     pobj
# ,                                                 PUNCT     punct
# there                                             PRON      expl
# is                                                AUX       ROOT
# a                                                 DET       det
# possible                                          ADJ       attr
# out                                               SCONJ     prep
# of                                                ADP       prep
# bounds                                            NOUN      pobj
# write                                             VERB      advcl
# due                                               ADP       prep
# to                                                ADP       pcomp
# a                                                 DET       det
# missing                                           VERB      amod
# bounds                                            NOUN      compound
# check                                             VERB      pobj
# .                                                 PUNCT     punct
# This                                              DET       nsubj
# could                                             VERB      aux
# lead                                              VERB      ROOT
# to                                                ADP       prep
# local                                             ADJ       amod
# escalation                                        NOUN      pobj
# of                                                ADP       prep
# privilege                                         NOUN      pobj
# with                                              ADP       prep
# System                                            NOUN      compound
# execution                                         NOUN      compound
# privileges                                        NOUN      pobj
# needed                                            VERB      acl
# .                                                 PUNCT     punct
# User                                              NOUN      compound
# interaction                                       NOUN      nsubjpass
# is                                                AUX       auxpass
# not                                               PART      neg
# needed                                            VERB      ROOT
# for                                               ADP       prep
# exploitation                                      NOUN      pobj
# .                                                 PUNCT     punct
# Product                                           NOUN      ROOT
# :                                                 PUNCT     punct
# AndroidVersions                                   X         ROOT
# :                                                 PUNCT     punct
# Android-8.0                                       PROPN     dep
# Android-8.1                                       PROPN     dep
# Android-9                                         PROPN     punct
# Android-10Android                                 NOUN      ROOT
# ID                                                PROPN     ROOT
# :                                                 PUNCT     punct
# A-141552859                                       NUM       appos
#
#                                                  SPACE
# In                                                ADP       prep
# rw_i93_send_cmd_write_single_block                NOUN      pobj
# of                                                ADP       prep
# rw_i93.cc                                         PROPN     pobj
# ,                                                 PUNCT     punct
# there                                             PRON      expl
# is                                                AUX       ROOT
# a                                                 DET       det
# possible                                          ADJ       amod
# information                                       NOUN      compound
# disclosure                                        NOUN      attr
# of                                                ADP       prep
# heap                                              NOUN      compound
# memory                                            NOUN      pobj
# due                                               ADJ       prep
# to                                                ADP       pcomp
# uninitialized                                     ADJ       amod
# data                                              NOUN      pobj
# .                                                 PUNCT     punct
# This                                              DET       nsubj
# could                                             VERB      aux
# lead                                              VERB      ROOT
# to                                                ADP       prep
# remote                                            ADJ       amod
# information                                       NOUN      compound
# disclosure                                        NOUN      pobj
# in                                                ADP       prep
# the                                               DET       det
# NFC                                               PROPN     compound
# server                                            NOUN      pobj
# with                                              ADP       prep
# no                                                DET       det
# additional                                        ADJ       amod
# execution                                         NOUN      compound
# privileges                                        NOUN      pobj
# needed                                            VERB      acl
# .                                                 PUNCT     punct
# User                                              PROPN     compound
# interaction                                       NOUN      nsubjpass
# is                                                AUX       auxpass
# needed                                            VERB      ROOT
# for                                               ADP       prep
# exploitation                                      NOUN      pobj
# .                                                 PUNCT     punct
# Product                                           NOUN      ROOT
# :                                                 PUNCT     punct
# Android                                           PROPN     compound
# Versions                                          NOUN      ROOT
# :                                                 PUNCT     punct
# Android-8.0                                       PROPN     appos
# ,                                                 PUNCT     punct
# Android-8.1                                       PROPN     npadvmod
# ,                                                 PUNCT     punct
# Android-9                                         PROPN     npadvmod
# ,                                                 PUNCT     punct
# and                                               CCONJ     cc
# Android-10                                        PROPN     compound
# Android                                           PROPN     compound
# ID                                                PROPN     conj
# :                                                 PUNCT     punct
# A-139738828                                       NOUN      appos
#
#                                                  SPACE
# In                                                ADP       prep
# flattenString8                                    NOUN      pobj
# of                                                ADP       prep
# Sensor.cpp                                        PROPN     pobj
# ,                                                 PUNCT     punct
# there                                             PRON      expl
# is                                                AUX       ROOT
# a                                                 DET       det
# possible                                          ADJ       amod
# information                                       NOUN      compound
# disclosure                                        NOUN      attr
# of                                                ADP       prep
# heap                                              NOUN      compound
# memory                                            NOUN      pobj
# due                                               ADJ       prep
# to                                                ADP       pcomp
# uninitialized                                     ADJ       amod
# data                                              NOUN      pobj
# .                                                 PUNCT     punct
# This                                              DET       nsubj
# could                                             VERB      aux
# lead                                              VERB      ROOT
# to                                                ADP       prep
# local                                             ADJ       amod
# information                                       NOUN      compound
# disclosure                                        NOUN      pobj
# with                                              ADP       prep
# no                                                DET       det
# additional                                        ADJ       amod
# execution                                         NOUN      compound
# privileges                                        NOUN      pobj
# needed                                            VERB      acl
# .                                                 PUNCT     punct
# User                                              NOUN      compound
# interaction                                       NOUN      nsubjpass
# is                                                AUX       auxpass
# not                                               PART      neg
# needed                                            VERB      ROOT
# for                                               ADP       prep
# exploitation                                      NOUN      pobj
# .                                                 PUNCT     punct
# Product                                           NOUN      ROOT
# :                                                 PUNCT     punct
# Android                                           PROPN     compound
# Versions                                          NOUN      ROOT
# :                                                 PUNCT     punct
# Android-8.0                                       PROPN     appos
# ,                                                 PUNCT     punct
# Android-8.1                                       PROPN     npadvmod
# ,                                                 PUNCT     punct
# Android-9                                         PROPN     npadvmod
# ,                                                 PUNCT     punct
# and                                               CCONJ     cc
# Android-10                                        PROPN     compound
# Android                                           PROPN     compound
# ID                                                PROPN     conj
# :                                                 PUNCT     punct
# A-141890807                                       NUM       ROOT
#
#                                                  SPACE
# In                                                ADP       prep
# LowEnergyClient::MtuChangedCallback               NOUN      pobj
# of                                                ADP       prep
# low_energy_client.cc                              NOUN      pobj
# ,                                                 PUNCT     punct
# there                                             PRON      expl
# is                                                AUX       ROOT
# a                                                 DET       det
# possible                                          ADJ       attr
# out                                               SCONJ     prep
# of                                                ADP       prep
# bounds                                            NOUN      pobj
# read                                              VERB      acl
# due                                               ADP       prep
# to                                                ADP       pcomp
# a                                                 DET       det
# race                                              NOUN      compound
# condition                                         NOUN      pobj
# .                                                 PUNCT     punct
# This                                              DET       nsubj
# could                                             VERB      aux
# lead                                              VERB      ROOT
# to                                                ADP       prep
# local                                             ADJ       amod
# information                                       NOUN      compound
# disclosure                                        NOUN      pobj
# with                                              ADP       prep
# no                                                DET       det
# additional                                        ADJ       amod
# execution                                         NOUN      compound
# privileges                                        NOUN      pobj
# needed                                            VERB      acl
# .                                                 PUNCT     punct
# User                                              NOUN      compound
# interaction                                       NOUN      nsubjpass
# is                                                AUX       auxpass
# not                                               PART      neg
# needed                                            VERB      ROOT
# for                                               ADP       prep
# exploitation                                      NOUN      pobj
# .                                                 PUNCT     punct
# Product                                           NOUN      ROOT
# :                                                 PUNCT     punct
# Android                                           PROPN     compound
# Versions                                          NOUN      ROOT
# :                                                 PUNCT     punct
# Android-8.0                                       PROPN     appos
# ,                                                 PUNCT     punct
# Android-8.1                                       PROPN     npadvmod
# ,                                                 PUNCT     punct
# Android-9                                         PROPN     npadvmod
# ,                                                 PUNCT     punct
# and                                               CCONJ     cc
# Android-10                                        PROPN     compound
# Android                                           PROPN     compound
# ID                                                PROPN     conj
# :                                                 PUNCT     punct
# A-142558228                                       ADP       ROOT
#
#                                                  SPACE
# In                                                ADP       prep
# calc_vm_may_flags                                 PROPN     pobj
# of                                                ADP       prep
# ashmem.c                                          PROPN     pobj
# ,                                                 PUNCT     punct
# there                                             PRON      expl
# is                                                AUX       ROOT
# a                                                 DET       det
# possible                                          ADJ       amod
# arbitrary                                         ADJ       amod
# write                                             NOUN      attr
# to                                                ADP       prep
# shared                                            VERB      amod
# memory                                            NOUN      pobj
# due                                               ADP       amod
# to                                                ADP       pcomp
# a                                                 DET       det
# permissions                                       NOUN      compound
# bypass                                            NOUN      pobj
# .                                                 PUNCT     punct
# This                                              DET       nsubj
# could                                             VERB      aux
# lead                                              VERB      ROOT
# to                                                ADP       prep
# local                                             ADJ       amod
# escalation                                        NOUN      pobj
# of                                                ADP       prep
# privilege                                         NOUN      pobj
# by                                                ADP       prep
# corrupting                                        VERB      pcomp
# memory                                            NOUN      dobj
# shared                                            VERB      acl
# between                                           ADP       prep
# processes                                         NOUN      pobj
# ,                                                 PUNCT     punct
# with                                              ADP       mark
# no                                                DET       det
# additional                                        ADJ       amod
# execution                                         NOUN      compound
# privileges                                        NOUN      nsubj
# needed                                            VERB      advcl
# .                                                 PUNCT     punct
# User                                              NOUN      compound
# interaction                                       NOUN      nsubjpass
# is                                                AUX       auxpass
# not                                               PART      neg
# needed                                            VERB      ROOT
# for                                               ADP       prep
# exploitation                                      NOUN      pobj
# .                                                 PUNCT     punct
# Product                                           NOUN      ROOT
# :                                                 PUNCT     punct
# Android                                           PROPN     compound
# Versions                                          PROPN     ROOT
# :                                                 PUNCT     punct
# Android                                           PROPN     compound
# kernel                                            NOUN      compound
# Android                                           PROPN     compound
# ID                                                PROPN     ROOT
# :                                                 PUNCT     punct
# A-142938932                                       NOUN      ROOT
#
#                                                  SPACE
# In                                                ADP       prep
# fpc_ta_get_build_info                             NOUN      pobj
# of                                                ADP       prep
# fpc_ta_kpi.c                                      PROPN     pobj
# ,                                                 PUNCT     punct
# there                                             PRON      expl
# is                                                AUX       ROOT
# a                                                 DET       det
# possible                                          ADJ       attr
# out                                               SCONJ     prep
# of                                                ADP       prep
# bounds                                            NOUN      pobj
# write                                             VERB      advcl
# due                                               ADP       prep
# to                                                ADP       pcomp
# a                                                 DET       det
# missing                                           VERB      amod
# bounds                                            NOUN      compound
# check                                             VERB      pobj
# .                                                 PUNCT     punct
# This                                              DET       nsubj
# could                                             VERB      aux
# lead                                              VERB      ROOT
# to                                                ADP       prep
# local                                             ADJ       amod
# escalation                                        NOUN      pobj
# of                                                ADP       prep
# privilege                                         NOUN      pobj
# with                                              ADP       prep
# System                                            NOUN      compound
# execution                                         NOUN      compound
# privileges                                        NOUN      pobj
# needed                                            VERB      acl
# .                                                 PUNCT     punct
# User                                              NOUN      compound
# interaction                                       NOUN      nsubjpass
# is                                                AUX       auxpass
# not                                               PART      neg
# needed                                            VERB      ROOT
# for                                               ADP       prep
# exploitation                                      NOUN      pobj
# .                                                 PUNCT     punct
# Product                                           NOUN      ROOT
# :                                                 PUNCT     punct
# AndroidVersions                                   PROPN     ROOT
# :                                                 PUNCT     punct
# Android                                           NOUN      compound
# kernelAndroid                                     NOUN      ROOT
# ID                                                PROPN     dobj
# :                                                 PUNCT     punct
# A-137014293References                             NOUN      ROOT
# :                                                 PUNCT     punct
# N                                                 NOUN      ROOT
# /                                                 SYM       punct
# A                                                 NOUN      appos
#
#                                                  SPACE

# %%
dash = '-' * 80
print(dash)
print("{:<50}{:<10}".format("TEXT", "ENTITY"))
print(dash)    
for ent in doc.ents:
    # Print the entity text and its label
    print(f"{ent.text:<50}{ent.label_:<10}")
# Out:
# --------------------------------------------------------------------------------
# TEXT                                              ENTITY
# --------------------------------------------------------------------------------
# Android-8.1                                       GPE
# Android                                           PERSON
# Android-8.1                                       GPE
# Android                                           PERSON
# onCreate of InstallStart.java                     WORK_OF_ART
# Android Versions:                                 ORG
# rw_i93_send_cmd_write_single_block of rw_i93.cc   PERSON
# Android                                           PERSON
# Android-8.1                                       GPE
# Android                                           PERSON
# Sensor.cpp                                        ORG
# Android-8.1                                       GPE
# Android                                           PERSON
# LowEnergyClient::MtuChangedCallback               GPE
# Android Versions: Android-8.0                     ORG
# Android-8.1                                       GPE
# Android                                           PERSON
# Android                                           PERSON
# System                                            NORP
# N/A
#                                               ORG

# %%
# Analyze syntax
print("Noun phrases:")
pp.pprint(set([chunk.text for chunk in doc.noun_chunks]))
# Out:
# Noun phrases:
# {   '/A',
#     'A-137014293References',
#     'A-139738828',
#     'A-140055304',
#     'A-140195904',
#     'A-142938932',
#     'ActivityManagerService.java',
#     'Android Versions',
#     'Android kernel Android ID',
#     'Android kernelAndroid',
#     'Android-10 Android ID',
#     'Android-8.0',
#     'Android-8.0 Android ID',
#     'Android-8.0 Android-8.1 Android-9 Android-10Android',
#     'AndroidVersions',
#     'ID',
#     'LowEnergyClient::MtuChangedCallback',
#     'N',
#     'Product',
#     'Sensor.cpp',
#     'System execution privileges',
#     'User interaction',
#     'WallpaperManagerService.java',
#     'a permissions bypass',
#     'a possible arbitrary write',
#     'a possible information disclosure',
#     'a possible package validation bypass',
#     'a possible sysui crash',
#     'a race condition',
#     'a use',
#     'ashmem.c',
#     'bounds',
#     'btm_acl.cc',
#     'btm_read_remote_ext_features_complete',
#     'calc_vm_may_flags',
#     'check',
#     'exploitation',
#     'exploitation Product',
#     'flattenString8',
#     'fpc_ta_get_build_info',
#     'fpc_ta_kpi.c',
#     'generateCrop',
#     'getProcessRecordLocked',
#     'heap memory',
#     'ih264d_api.c',
#     'ih264d_init_decoder',
#     'image',
#     'isolated apps',
#     'local denial',
#     'local escalation',
#     'local information disclosure',
#     'low_energy_client.cc',
#     'maximum texture size',
#     'memory',
#     'no additional execution privileges',
#     'onCreate',
#     'privilege',
#     'processes',
#     'remote code execution',
#     'remote information disclosure',
#     'rw_i93.cc',
#     'rw_i93_send_cmd_write_single_block',
#     'service',
#     'shared memory',
#     'the NFC server',
#     'uninitialized data',
#     'use'}

# %%
print("Verbs:")
pp.pprint(set([token.lemma_ for token in doc if token.pos_ == "VERB"]))
# Out:
# Verbs:
# {   'check',
#     'corrupt',
#     'could',
#     'exceed',
#     'handle',
#     'isolate',
#     'lead',
#     'miss',
#     'need',
#     'read',
#     'share',
#     'write'}
